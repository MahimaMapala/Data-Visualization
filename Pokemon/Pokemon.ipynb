# %% [markdown]
# <a name="section-one"></a>
# # **Importing Libraries**

# %%
import os

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abcsds/pokemon")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\uniat\.cache\kagglehub\datasets\abcsds\pokemon\versions\2

# %%
df_orginal = pd.read_csv(path+"//Pokemon.csv")
df = df_orginal.copy()
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49       65       65     45           1      False
# 1  2                Ivysaur  Grass  Poison    405  60      62       63       80       80     60           1      False
# 2  3               Venusaur  Grass  Poison    525  80      82       83      100      100     80           1      False
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122      120     80           1      False
# 4  4             Charmander   Fire     NaN    309  39      52       43       60       50     65           1      False

# %% [markdown]
# <a name="section-two"></a>
# # **EDA (Exploratory Data Analysis)**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
print(f'Shape     : {df.shape}\n'
      f'Size      : {df.size}\n'
      f'Dimension : {df.ndim}')
# Out:
# Shape     : (800, 13)
# Size      : 10400
# Dimension : 2

# %%
print(f'Total duplicated: {sum(df.duplicated())}')
# Out:
# Total duplicated: 0

# %%
print(pd.concat([df.isnull().sum(), df.isnull().sum()/len(df)*100],
                 keys=['Number of Missing Values', 'Ratio of Missing Values'],
                 axis=1))
# Out:
#             Number of Missing Values  Ratio of Missing Values
# #                                  0                     0.00
# Name                               0                     0.00
# Type 1                             0                     0.00
# Type 2                           386                    48.25
# Total                              0                     0.00
# HP                                 0                     0.00
# Attack                             0                     0.00
# Defense                            0                     0.00
# Sp. Atk                            0                     0.00
# Sp. Def                            0                     0.00
# Speed                              0                     0.00
# Generation                         0                     0.00
# Legendary                          0                     0.00

# %%
df.describe().T
# Out:
#             count   mean    std    min    25%    50%    75%    max
# #          800.00 362.81 208.34   1.00 184.75 364.50 539.25 721.00
# Total      800.00 435.10 119.96 180.00 330.00 450.00 515.00 780.00
# HP         800.00  69.26  25.53   1.00  50.00  65.00  80.00 255.00
# Attack     800.00  79.00  32.46   5.00  55.00  75.00 100.00 190.00
# Defense    800.00  73.84  31.18   5.00  50.00  70.00  90.00 230.00
# Sp. Atk    800.00  72.82  32.72  10.00  49.75  65.00  95.00 194.00
# Sp. Def    800.00  71.90  27.83  20.00  50.00  70.00  90.00 230.00
# Speed      800.00  68.28  29.06   5.00  45.00  65.00  90.00 180.00
# Generation 800.00   3.32   1.66   1.00   2.00   3.00   5.00   6.00

# %%
# Displaying the correlation matrix of numeric columns
df.corr(numeric_only=True).style.background_gradient()
# Out:
# <style type="text/css">
# #T_1c98c_row0_col0, #T_1c98c_row1_col1, #T_1c98c_row2_col2, #T_1c98c_row3_col3, #T_1c98c_row4_col4, #T_1c98c_row5_col5, #T_1c98c_row6_col6, #T_1c98c_row7_col7, #T_1c98c_row8_col8, #T_1c98c_row9_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1c98c_row0_col1, #T_1c98c_row6_col0 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_1c98c_row0_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_1c98c_row0_col3, #T_1c98c_row0_col5, #T_1c98c_row5_col8 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_1c98c_row0_col4, #T_1c98c_row0_col9, #T_1c98c_row2_col8, #T_1c98c_row5_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_1c98c_row0_col6 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_1c98c_row0_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_1c98c_row0_col8, #T_1c98c_row8_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_1c98c_row1_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_1c98c_row1_col2 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_1c98c_row1_col3 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_1c98c_row1_col4 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_1c98c_row1_col5, #T_1c98c_row5_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_1c98c_row1_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_1c98c_row1_col7 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_1c98c_row1_col8 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_1c98c_row1_col9 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_1c98c_row2_col0, #T_1c98c_row4_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_1c98c_row2_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_1c98c_row2_col3 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_1c98c_row2_col4, #T_1c98c_row9_col2 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_1c98c_row2_col5 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_1c98c_row2_col6 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_1c98c_row2_col7, #T_1c98c_row4_col2, #T_1c98c_row4_col5 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_1c98c_row2_col9, #T_1c98c_row5_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_1c98c_row3_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_1c98c_row3_col1 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_1c98c_row3_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_1c98c_row3_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_1c98c_row3_col5 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_1c98c_row3_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_1c98c_row3_col7 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_1c98c_row3_col8 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_1c98c_row3_col9 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_1c98c_row4_col1 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_1c98c_row4_col3 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_1c98c_row4_col6 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_1c98c_row4_col7 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_1c98c_row4_col8 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_1c98c_row4_col9 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_1c98c_row5_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_1c98c_row5_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_1c98c_row5_col6 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_1c98c_row5_col7, #T_1c98c_row6_col5 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_1c98c_row5_col9 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_1c98c_row6_col1 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_1c98c_row6_col2, #T_1c98c_row9_col7 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_1c98c_row6_col3 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_1c98c_row6_col4 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_1c98c_row6_col7 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_1c98c_row6_col8 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_1c98c_row6_col9, #T_1c98c_row9_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_1c98c_row7_col0, #T_1c98c_row7_col4, #T_1c98c_row7_col8, #T_1c98c_row8_col1, #T_1c98c_row8_col2, #T_1c98c_row8_col3, #T_1c98c_row8_col5, #T_1c98c_row8_col6, #T_1c98c_row8_col7, #T_1c98c_row8_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1c98c_row7_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_1c98c_row7_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_1c98c_row7_col3 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_1c98c_row7_col5 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_1c98c_row7_col6, #T_1c98c_row9_col4 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_1c98c_row7_col9 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_1c98c_row8_col4 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_1c98c_row9_col0 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_1c98c_row9_col1 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_1c98c_row9_col5 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_1c98c_row9_col6 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_1c98c_row9_col8 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# </style>
# <table id="T_1c98c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c98c_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_1c98c_level0_col1" class="col_heading level0 col1" >Total</th>
#       <th id="T_1c98c_level0_col2" class="col_heading level0 col2" >HP</th>
#       <th id="T_1c98c_level0_col3" class="col_heading level0 col3" >Attack</th>
#       <th id="T_1c98c_level0_col4" class="col_heading level0 col4" >Defense</th>
#       <th id="T_1c98c_level0_col5" class="col_heading level0 col5" >Sp. Atk</th>
#       <th id="T_1c98c_level0_col6" class="col_heading level0 col6" >Sp. Def</th>
#       <th id="T_1c98c_level0_col7" class="col_heading level0 col7" >Speed</th>
#       <th id="T_1c98c_level0_col8" class="col_heading level0 col8" >Generation</th>
#       <th id="T_1c98c_level0_col9" class="col_heading level0 col9" >Legendary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c98c_level0_row0" class="row_heading level0 row0" >#</th>
#       <td id="T_1c98c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1c98c_row0_col1" class="data row0 col1" >0.119813</td>
#       <td id="T_1c98c_row0_col2" class="data row0 col2" >0.097614</td>
#       <td id="T_1c98c_row0_col3" class="data row0 col3" >0.102298</td>
#       <td id="T_1c98c_row0_col4" class="data row0 col4" >0.094786</td>
#       <td id="T_1c98c_row0_col5" class="data row0 col5" >0.088759</td>
#       <td id="T_1c98c_row0_col6" class="data row0 col6" >0.085817</td>
#       <td id="T_1c98c_row0_col7" class="data row0 col7" >0.010733</td>
#       <td id="T_1c98c_row0_col8" class="data row0 col8" >0.982516</td>
#       <td id="T_1c98c_row0_col9" class="data row0 col9" >0.153396</td>
#     </tr>
#     <tr>
#       <th id="T_1c98c_level0_row1" class="row_heading level0 row1" >Total</th>
#       <td id="T_1c98c_row1_col0" class="data row1 col0" >0.119813</td>
#       <td id="T_1c98c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1c98c_row1_col2" class="data row1 col2" >0.618748</td>
#       <td id="T_1c98c_row1_col3" class="data row1 col3" >0.736211</td>
#       <td id="T_1c98c_row1_col4" class="data row1 col4" >0.612787</td>
#       <td id="T_1c98c_row1_col5" class="data row1 col5" >0.747250</td>
#       <td id="T_1c98c_row1_col6" class="data row1 col6" >0.717609</td>
#       <td id="T_1c98c_row1_col7" class="data row1 col7" >0.575943</td>
#       <td id="T_1c98c_row1_col8" class="data row1 col8" >0.048384</td>
#       <td id="T_1c98c_row1_col9" class="data row1 col9" >0.501758</td>
#     </tr>
#     <tr>
#       <th id="T_1c98c_level0_row2" class="row_heading level0 row2" >HP</th>
#       <td id="T_1c98c_row2_col0" class="data row2 col0" >0.097614</td>
#       <td id="T_1c98c_row2_col1" cl

# %% [markdown]
# <a name="section-three"></a>
# # **Data Cleaning & Reduction**

# %%
df.rename(columns={'#':'ID',
                   'Sp. Atk': 'Special Attack',
                   'Sp. Def': 'Special Defense'}, inplace=True)

df.columns = [x.replace(" ", "_").lower() for x in df.columns]

# %%
df['type_2'] = df['type_2'].replace(np.nan, "No_2nd_Type")

# %%
# In further steps "name" and "total" variables will also be dropped.
df.drop(['id'], axis=1, inplace=True)

# %% [markdown]
# # **Feature Extraction**

# %%
df['is_dual_type'] = df['type_2'].apply(lambda x: '0' if x=='No_2nd_Type' else '1')

# %%
df['full_type'] = df['type_1'] + " - " + df['type_2']

# %% [markdown]
# # **Visualization**

# %% [markdown]
# <a name="section-v-one"></a>
# ### **Minumum and Maximum Skilled Pokemons**

# %%
skills = ['hp', 'attack', 'defense', 'special_attack', 'special_defense', 'speed']

max_skills_id = []
min_skills_id = []

for skill in skills:
  max_skills_id.append(df.loc[df[skill].idxmax()].name)
  min_skills_id.append(df.loc[df[skill].idxmin()].name)

print("Highlighting the minimum values for each skill")
df.iloc[min_skills_id,:].drop_duplicates().style.highlight_min(subset=skills, color = 'red')
# Out:
# Highlighting the minimum values for each skill
# <style type="text/css">
# #T_bc9fe_row0_col4, #T_bc9fe_row1_col5, #T_bc9fe_row1_col6, #T_bc9fe_row2_col7, #T_bc9fe_row2_col9, #T_bc9fe_row3_col8 {
#   background-color: red;
# }
# </style>
# <table id="T_bc9fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc9fe_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_bc9fe_level0_col1" class="col_heading level0 col1" >type_1</th>
#       <th id="T_bc9fe_level0_col2" class="col_heading level0 col2" >type_2</th>
#       <th id="T_bc9fe_level0_col3" class="col_heading level0 col3" >total</th>
#       <th id="T_bc9fe_level0_col4" class="col_heading level0 col4" >hp</th>
#       <th id="T_bc9fe_level0_col5" class="col_heading level0 col5" >attack</th>
#       <th id="T_bc9fe_level0_col6" class="col_heading level0 col6" >defense</th>
#       <th id="T_bc9fe_level0_col7" class="col_heading level0 col7" >special_attack</th>
#       <th id="T_bc9fe_level0_col8" class="col_heading level0 col8" >special_defense</th>
#       <th id="T_bc9fe_level0_col9" class="col_heading level0 col9" >speed</th>
#       <th id="T_bc9fe_level0_col10" class="col_heading level0 col10" >generation</th>
#       <th id="T_bc9fe_level0_col11" class="col_heading level0 col11" >legendary</th>
#       <th id="T_bc9fe_level0_col12" class="col_heading level0 col12" >is_dual_type</th>
#       <th id="T_bc9fe_level0_col13" class="col_heading level0 col13" >full_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc9fe_level0_row0" class="row_heading level0 row0" >316</th>
#       <td id="T_bc9fe_row0_col0" class="data row0 col0" >Shedinja</td>
#       <td id="T_bc9fe_row0_col1" class="data row0 col1" >Bug</td>
#       <td id="T_bc9fe_row0_col2" class="data row0 col2" >Ghost</td>
#       <td id="T_bc9fe_row0_col3" class="data row0 col3" >236</td>
#       <td id="T_bc9fe_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_bc9fe_row0_col5" class="data row0 col5" >90</td>
#       <td id="T_bc9fe_row0_col6" class="data row0 col6" >45</td>
#       <td id="T_bc9fe_row0_col7" class="data row0 col7" >30</td>
#       <td id="T_bc9fe_row0_col8" class="data row0 col8" >30</td>
#       <td id="T_bc9fe_row0_col9" class="data row0 col9" >40</td>
#       <td id="T_bc9fe_row0_col10" class="data row0 col10" >3</td>
#       <td id="T_bc9fe_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_bc9fe_row0_col12" class="data row0 col12" >1</td>
#       <td id="T_bc9fe_row0_col13" class="data row0 col13" >Bug - Ghost</td>
#     </tr>
#     <tr>
#       <th id="T_bc9fe_level0_row1" class="row_heading level0 row1" >121</th>
#       <td id="T_bc9fe_row1_col0" class="data row1 col0" >Chansey</td>
#       <td id="T_bc9fe_row1_col1" class="data row1 col1" >Normal</td>
#       <td id="T_bc9fe_row1_col2" class="data row1 col2" >No_2nd_Type</td>
#       <td id="T_bc9fe_row1_col3" class="data row1 col3" >450</td>
#       <td id="T_bc9fe_row1_col4" class="data row1 col4" >250</td>
#       <td id="T_bc9fe_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_bc9fe_row1_col6" class="data row1 col6" >5</td>
#       <td id="T_bc9fe_row1_col7" class="data row1 col7" >35</td>
#       <td id="T_bc9fe_row1_col8" class="data row1 col8" >105</td>
#       <td id="T_bc9fe_row1_col9" class="data row1 col9" >50</td>
#       <td id="T_bc9fe_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_bc9fe_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_bc9fe_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_bc9fe_row1_col13" class="data row1 col13" >Normal - No_2nd_Type</td>
#     </tr>
#     <tr>
#       <th id="T_bc9fe_level0_row2" class="row_heading level0 row2" >230</th>
#       <td id="T_bc9fe_row2_col0" class="data row2 col0" >Shuckle</td>
#       <td id="T_bc9fe_row2_col1" class="data row2 col1" >Bug</td>
#       <td id="T_bc9fe_row2_col2" class="data row2 col2" >Rock</td>
#       <td id="T_bc9fe_row2_col3" class="data row2 col3" >505</td>
#       <td id="T_bc9fe_row2_col4" class="data row2 col4" >20</td>
#       <td id="T_bc9fe_row2_col5" class="data row2 col5" >10</td>
#       <td id="T_bc9fe_row2_col6" class="data row2 col6" >230</td>
#       <td id="T_bc9fe_row2_col7" class="data row2 col7" >10</td>
#       <td id="T_bc9fe_row2_col8" class="data row2 col8" >230</td>
#       <td id="T_bc9fe_row2_col9" class="data row2 col9" >5</td>
#       <td id="T_bc9fe_row2_col10" class="data row2 col10" >2</td>
#       <td id="T_bc9fe_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_bc9fe_row2_col12" class="data row2 col12" >1</td>
#       <td id="T_bc9fe_row2_col13" class="data row2 col13" >Bug - Rock</td>
#     </tr>
#     <tr>
#       <th id="T_bc9fe_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_bc9fe_row3_col0" class="data row3 col0" >Caterpie</td>
#       <td id="T_bc9fe_row3_col1" class="data row3 col1" >Bug</td>
#       <td id="T_bc9fe_row3_col2" class="data row3 col2" >No_2nd_Type</td>
#       <td id="T_bc9fe_row3_col3" class="data row3 col3" >195</td>
#       <td id="T_bc9fe_row3_col4" class="data row3 col4" >45</td>
#       <td id="T_bc9fe_row3_col5" class="data row3 col5" >30</td>
#       <td id="T_bc9fe_row3_col6" class="data row3 col6" >35</td>
#       <td id="T_bc9fe_row3_col7" class="data row3 col7" >20</td>
#       <td id="T_bc9fe_row3_col8" class="data row3 col8" >20</td>
#       <td id="T_bc9fe_row3_col9" class="data row3 col9" >45</td>
#       <td id="T_bc9fe_row3_col10" class="data row3 col10" >1</td>
#       <td id="T_bc9fe_row3_col11" class="data row3 col11" >False</td>
#       <td id="T_bc9fe_row3_col12" class="data row3 col12" >0</td>
#       <td id="T_bc9fe_row3_col13" class="data row3 col13" >Bug - No_2nd_Type</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Highlighting the Maximum values for each skill")
df.iloc[max_skills_id,:].style.highlight_max(subset=skills, color = 'lightgreen')
# Out:
# Highlighting the Maximum values for each skill
# <style type="text/css">
# #T_0058d_row0_col4, #T_0058d_row1_col5, #T_0058d_row2_col6, #T_0058d_row3_col7, #T_0058d_row4_col6, #T_0058d_row4_col8, #T_0058d_row5_col9 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0058d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0058d_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_0058d_level0_col1" class="col_heading level0 col1" >type_1</th>
#       <th id="T_0058d_level0_col2" class="col_heading level0 col2" >type_2</th>
#       <th id="T_0058d_level0_col3" class="col_heading level0 col3" >total</th>
#       <th id="T_0058d_level0_col4" class="col_heading level0 col4" >hp</th>
#       <th id="T_0058d_level0_col5" class="col_heading level0 col5" >attack</th>
#       <th id="T_0058d_level0_col6" class="col_heading level0 col6" >defense</th>
#       <th id="T_0058d_level0_col7" class="col_heading level0 col7" >special_attack</th>
#       <th id="T_0058d_level0_col8" class="col_heading level0 col8" >special_defense</th>
#       <th id="T_0058d_level0_col9" class="col_heading level0 col9" >speed</th>
#       <th id="T_0058d_level0_col10" class="col_heading level0 col10" >generation</th>
#       <th id="T_0058d_level0_col11" class="col_heading level0 col11" >legendary</th>
#       <th id="T_0058d_level0_col12" class="col_heading level0 col12" >is_dual_type</th>
#       <th id="T_0058d_level0_col13" class="col_heading level0 col13" >full_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0058d_level0_row0" class="row_heading level0 row0" >261</th>
#       <td id="T_0058d_row0_col0" class="data row0 col0" >Blissey</td>
#       <td id="T_0058d_row0_col1" class="data row0 col1" >Normal</td>
#       <td id="T_0058d_row0_col2" class="data row0 col2" >No_2nd_Type</td>
#       <td id="T_0058d_row0_col3" class="data row0 col3" >540</td>
#       <td id="T_0058d_row0_col4" class="data row0 col4" >255</td>
#       <td id="T_0058d_row0_col5" class="data row0 col5" >10</td>
#       <td id="T_0058d_row0_col6" class="data row0 col6" >10</td>
#       <td id="T_0058d_row0_col7" class="data row0 col7" >75</td>
#       <td id="T_0058d_row0_col8" class="data row0 col8" >135</td>
#       <td id="T_0058d_row0_col9" class="data row0 col9" >55</td>
#       <td id="T_0058d_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_0058d_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_0058d_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_0058d_row0_col13" class="data row0 col13" >Normal - No_2nd_Type</td>
#     </tr>
#     <tr>
#       <th id="T_0058d_level0_row1" class="row_heading level0 row1" >163</th>
#       <td id="T_0058d_row1_col0" class="data row1 col0" >MewtwoMega Mewtwo X</td>
#       <td id="T_0058d_row1_col1" class="data row1 col1" >Psychic</td>
#       <td id="T_0058d_row1_col2" class="data row1 col2" >Fighting</td>
#       <td id="T_0058d_row1_col3" class="data row1 col3" >780</td>
#       <td id="T_0058d_row1_col4" class="data row1 col4" >106</td>
#       <td id="T_0058d_row1_col5" class="data row1 col5" >190</td>
#       <td id="T_0058d_row1_col6" class="data row1 col6" >100</td>
#       <td id="T_0058d_row1_col7" class="data row1 col7" >154</td>
#       <td id="T_0058d_row1_col8" class="data row1 col8" >100</td>
#       <td id="T_0058d_row1_col9" class="data row1 col9" >130</td>
#       <td id="T_0058d_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_0058d_row1_col11" class="data row1 col11" >True</td>
#       <td id="T_0058d_row1_col12" class="data row1 col12" >1</td>
#       <td id="T_0058d_row1_col13" class="data row1 col13" >Psychic - Fighting</td>
#     </tr>
#     <tr>
#       <th id="T_0058d_level0_row2" class="row_heading level0 row2" >224</th>
#       <td id="T_0058d_row2_col0" class="data row2 col0" >SteelixMega Steelix</td>
#       <td id="T_0058d_row2_col1" class="data row2 col1" >Steel</td>
#       <td id="T_0058d_row2_col2" class="data row2 col2" >Ground</td>
#       <td id="T_0058d_row2_col3" class="data row2 col3" >610</td>
#       <td id="T_0058d_row2_col4" class="data row2 col4" >75</td>
#       <td id="T_0058d_row2_col5" class="data row2 col5" >125</td>
#       <td id="T_0058d_row2_col6" class="data row2 col6" >230</td>
#       <td id="T_0058d_row2_col7" class="data row2 col7" >55</td>
#       <td id="T_0058d_row2_col8" class="data row2 col8" >95</td>
#       <td id="T_0058d_row2_col9" class="data row2 col9" >30</td>
#       <td id="T_0058d_row2_col10" class="data row2 col10" >2</td>
#       <td id="T_0058d_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_0058d_row2_col12" class="data row2 col12" >1</td>
#       <td id="T_0058d_row2_col13" class="data row2 col13" >Steel - Ground</td>
#     </tr>
#     <tr>
#       <th id="T_0058d_level0_row3" class="row_heading level0 row3" >164</th>
#       <td id="T_0058d_row3_col0" class="data row3 col0" >MewtwoMega Mewtwo Y</td>
#       <td id="T_0058d_row3_col1" class="data row3 col1" >Psychic</td>
#       <td id="T_0058d_row3_col2" class="data row3 col2" >No_2nd_Type</td>
#       <td id="T_0058d_row3_col3" class="data row3 col3" >780</td>
#       <td id="T_0058d_row3_col4" class="data row3 col4" >106</td>
#       <td id="T_0058d_row3_col5" class="data row3 col5" >150</td>
#       <td id="T_0058d_row3_col6" class="data row3 col6" >70</td>
#       <td id="T_0058d_row3_col7" class="data row3 col7" >194</td>
#       <td id="T_0058d_row3_col8" class="data row3 col8" >120</td>
#       <td id="T_0058d_row3_col9" class="data row3 col9" >140</td>
#       <td id="T_0058d_row3_col10" class="data row3 col10" >1</td>
#       <td id="T_0058d_row3_col11" class="data row3 col11" >True</td>
#       <td id="T_0058d_row3_col12" class="data row3 col12" >0</td>
#       <td id="T_0058d_row3_col13" class="data row3 col13" >Psychic - No_2nd_Type</td>
#     </tr>
#     <tr>
#       <th id="T_0058d_level0_row4" class="row_heading level0 row4" >230</th>
#       <td id="T_0058d_row4_col0" class="data row4 col0" >Shuckle</td>
#       <td id="T_0058d_row4_col1" class="data row4 col1" >Bug</td>
#       <td id="T_0058d_row4_col2" class="data row4 col2" >Rock</td>
#       <td id="T_0058d_row4_col3" class="data row4 col3" >505</td>
#       <td id="T_0058d_row4_col4" class="data row4 col4" >20</td>
#       <td id="T_0058d_row4_col5" class="data row4 col5" >10</td>
#       <td id="T_0058d_row4_col6" class="data row4 col6" >230</td>
#       <td id="T_0058d_row4_col7" class="data row4 col7" >10</td>
#       <td id="T_0058d_row4_col8" class="data row4 col8" >230</td>
#       <td id="T_0058d_row4_col9" class="data row4 col9" >5</td>
#       <td id="T_0058d_row4_col10" class="data row4 col10" >2</td>
#       <td id="T_0058d_row4_col11" class="data row4 col11" >False</td>
#       <td id="T_0058d_row4_col12" class="data row4 col12" >1</td>
#       <td id="T_0058d_row4_col13" class="data row4 col13" >Bug - Rock</td>
#     </tr>
#     <tr>
#       <th id="T_0058d_level0_row5" class="row_heading level0 row5" >431</th>
#       <td id="T_0058d_row5_col0" class="data row5 col0" >DeoxysSpeed Forme</td>
#       <td id="T_0058d_row5_col1" class="data row5 col1" >Psychic</td>
#       <td id="T_0058d_row5_col2" class="data row5 col2" >No_2nd_Type</td>
#       <td id="T_0058d_row5_col3" class="data row5 col3" >600</td>
#       <td id="T_0058d_row5_col4" class="data row5 col4" >50</td>
#       <td id="T_0058d_row5_col5" class="data row5 col5" >95</td>
#       <td id="T_0058d_row5_col6" class="data row5 col6" >90</td>
#       <td id="T_0058d_row5_col7" class="data row5 col7" >95</td>
#       <td id="T_0058d_row5_col8" class="data row5 col8" >90</td>
#       <td id="T_0058d_row5_col9" class="data row5 col9" >180</td>
#       <td id="T_0058d_row5_col10" class="data row5 col10" >3</td>
#       <td id="T_0058d_row5_col11" class="data row5 col11" >True</td>
#       <td id="T_0058d_row5_col12" class="data row5 col12" >0</td>
#       <td id="T_0058d_row5_col13" class="data row5 col13" >Psychic - No_2nd_Type</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a name="section-v-two"></a>
# ### **Average Scores for each Generation**

# %%
skills = ['hp', 'attack', 'defense', 'special_attack', 'special_defense', 'speed', 'total']

n_cols = 2
n_rows = (len(skills) - 1) // n_cols + 1

fig, axs = plt.subplots(n_rows, n_cols, figsize = (20, 20))
axs = axs.flatten()

for n, skill in enumerate(skills):
    ax = sns.barplot(x = df.groupby(['generation'])[skill].mean().index,
                     y = df.groupby(['generation'])[skill].mean().values,
                     ax=axs[n],
                     palette='Set3')

    axs[n].set_title(f"Average {skill} Score for Generations", fontsize=16)
    axs[n].set_xlabel("Generation", fontsize=11)
    ax.set_ylabel(f'Score', fontsize=11)

    for container in ax.containers:
        ax.bar_label(container, fmt='%.2f', fontsize=15, label_type='center')

    if not axs.flat[-1].lines:
        axs.flat[-1].set_visible(False)

plt.tight_layout(h_pad=3)
plt.show()

# %% [markdown]
# <a name="section-v-three"></a>
# ### **Skill Distributions**

# %%
def plot_histogram(dataframe, features, n_cols, statistic=False):
    n_rows = (len(features) - 1) // n_cols + 1

    fig, axs = plt.subplots(n_rows, n_cols, figsize = (20, 16))
    axs = axs.flatten()

    for n, feature in enumerate(features):
        ax = sns.histplot(dataframe[feature],
                          kde=True,
                          ax=axs[n])
        if statistic:
            ax.axvline(np.mean(dataframe[feature]), ls='--', c='r',
                       label=f"Mean: {np.mean(dataframe[feature]).round(2)}")
            ax.axvline(np.median(dataframe[feature]), ls='--', c='g',
                       label=f"Median: {np.median(dataframe[feature]).round(2)}")
            ax.legend()
        ax.set_title(f'{feature} Distribution')

    if not axs.flat[-1].lines:
        axs.flat[-1].set_visible(False)

    plt.tight_layout()
    plt.show()

plot_histogram(df, skills, 2, True)

# %% [markdown]
# <a name="section-v-five"></a>
# ### **Pie Chart of Generation**

# %%
plot_pie(df, 'generation', 'Generation Distribution', colors=sns.color_palette('Set3'))

# %% [markdown]
# <a name="section-v-six"></a>
# ### **Pokemon Stats**

# %%
skills = ['hp', 'attack', 'defense', 'special_attack', 'special_defense', 'speed']

def pokemon_stats(name):
    x = df[df["name"] == name]

    data = go.Scatterpolar(r = df.loc[x.index[0], skills].values,
                           theta = skills,
                           fill = 'toself',
                           line =  dict(color = 'dodgerblue'),
                           name = name)

    layout = go.Layout(polar = dict(radialaxis = dict(visible = False,
                                                      range = [0, x[skills].max().max()+20])),
                       showlegend = True,
                       title = f"{name} Stats",
                       title_x = 0.5)

    fig = go.Figure(data=data, layout=layout)
    iplot(fig, filename = "Two Pokemon stats")

pokemon_stats("MewtwoMega Mewtwo X")

# %% [markdown]
# <a name="section-v-seven"></a>
# ### **Comparing Two Pokemon Stats**

# %%
skills = ['hp', 'attack', 'defense', 'special_attack', 'special_defense', 'speed']

def compare_pokemons(first_name, second_name):
    x = df[df["name"] == first_name]
    y = df[df["name"] == second_name]

    trace0 = go.Scatterpolar(r = df.loc[x.index[0], skills].values,
                             theta = skills,
                             fill = 'toself',
                             line =  dict(color = '#92D1B3'),
                             name = first_name)

    trace1 = go.Scatterpolar(r = df.loc[y.index[0], skills].values,
                             theta = skills,
                             fill = 'toself',
                             line =  dict(color = 'orange'),
                             name = second_name)

    data = [trace0, trace1]

    layout = go.Layout(polar = dict(radialaxis = dict(visible = False,
                                                      range = [0, pd.concat([x,y])[skills].max().max()+10])),
                       showlegend = True,
                       title = f"{first_name} vs {second_name}",
                       title_x = 0.5)

    fig = go.Figure(data=data, layout=layout)
    iplot(fig, filename = "Two Pokemon stats")

compare_pokemons("Bulbasaur", "Charmander")

# %% [markdown]
# <a name="section-v-eight"></a>
# ### **Type 1 and Type 2 Heatmap**

# %%
plt.subplots(figsize=(20, 8))

sns.heatmap(df.groupby(['type_1', 'type_2']).size().unstack(),
            linewidths=1,
            annot=True,
            cmap="Blues")

plt.xticks(rotation=35)
plt.show()

# %% [markdown]
# <a name="section-v-nine"></a>
# ### **Pairplot**

# %%
df
# Out:
#                       name   type_1       type_2  total  hp  attack  defense  special_attack  special_defense  speed  generation  legendary is_dual_type           full_type
# 0                Bulbasaur    Grass       Poison    318  45      49       49              65               65     45           1      False            1      Grass - Poison
# 1                  Ivysaur    Grass       Poison    405  60      62       63              80               80     60           1      False            1      Grass - Poison
# 2                 Venusaur    Grass       Poison    525  80      82       83             100              100     80           1      False            1      Grass - Poison
# 3    VenusaurMega Venusaur    Grass       Poison    625  80     100      123             122              120     80           1      False            1      Grass - Poison
# 4               Charmander     Fire  No_2nd_Type    309  39      52       43              60               50     65           1      False            0  Fire - No_2nd_Type
# ..                     ...      ...          ...    ...  ..     ...      ...             ...              ...    ...         ...        ...          ...                 ...
# 795                Diancie     Rock        Fairy    600  50     100      150             100              150     50           6       True            1        Rock - Fairy
# 796    DiancieMega Diancie     Rock        Fairy    700  50     160      110             160              110    110           6       True            1        Rock - Fairy
# 797    HoopaHoopa Confined  Psychic        Ghost    600  80     110       60             150              130     70           6       True            1     Psychic - Ghost
# 798     HoopaHoopa Unbound  Psychic         Dark    680  80     160       60             170              130     80           6       True            1      Psychic - Dark
# 799              Volcanion     Fire        Water    600  80     110      120             130               90     70           6       True            1        Fire - Water
#
# [800 rows x 14 columns]

# %%
import plotly.figure_factory as ff

hist_data = [df['attack'],df['defense']]
group_labels = ['attack','defense']

fig = ff.create_distplot(hist_data, group_labels, bin_size=5)
iplot(fig, filename='Distplot of attack and defense')

# %%
t = go.Scatter3d(
    x=df["speed"],
    y=df["attack"],
    z=df["defense"],
    mode='markers',
    marker=dict(
        size=4,
        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.5
        ),
        opacity=1
    )
)
data = [t]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    ),
    xaxis=dict(title="Speed"),
    yaxis=dict(title="Attack"),
    title = "Speed vs Attack vs Defense"
)
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='3d-scatter')

# %%
df
# Out:
#                       name   type_1       type_2  total  hp  attack  defense  special_attack  special_defense  speed  generation  legendary is_dual_type           full_type
# 0                Bulbasaur    Grass       Poison    318  45      49       49              65               65     45           1      False            1      Grass - Poison
# 1                  Ivysaur    Grass       Poison    405  60      62       63              80               80     60           1      False            1      Grass - Poison
# 2                 Venusaur    Grass       Poison    525  80      82       83             100              100     80           1      False            1      Grass - Poison
# 3    VenusaurMega Venusaur    Grass       Poison    625  80     100      123             122              120     80           1      False            1      Grass - Poison
# 4               Charmander     Fire  No_2nd_Type    309  39      52       43              60               50     65           1      False            0  Fire - No_2nd_Type
# ..                     ...      ...          ...    ...  ..     ...      ...             ...              ...    ...         ...        ...          ...                 ...
# 795                Diancie     Rock        Fairy    600  50     100      150             100              150     50           6       True            1        Rock - Fairy
# 796    DiancieMega Diancie     Rock        Fairy    700  50     160      110             160              110    110           6       True            1        Rock - Fairy
# 797    HoopaHoopa Confined  Psychic        Ghost    600  80     110       60             150              130     70           6       True            1     Psychic - Ghost
# 798     HoopaHoopa Unbound  Psychic         Dark    680  80     160       60             170              130     80           6       True            1      Psychic - Dark
# 799              Volcanion     Fire        Water    600  80     110      120             130               90     70           6       True            1        Fire - Water
#
# [800 rows x 14 columns]

# %%
def checkpokemonperformance(x):
    x = df[df["name"] == x]
    data = (
      {"label": "hp", "sublabel": x["hp"].values[0],
       "range": [int(max(df["hp"])*0.5), int(max(df["hp"])*0.75), int(max(df["hp"]))], "performance": [int(max(df["hp"])*0.55),int(max(df["hp"])*0.70)], "point": [x["hp"].values[0]]},
      {"label": "attack", "sublabel": x["attack"].values[0],
       "range": [int(max(df["attack"])*0.5), int(max(df["attack"])*0.75), int(max(df["attack"]))], "performance": [int(max(df["attack"])*0.55),int(max(df["attack"])*0.70)], "point": [x["attack"].values[0]]},
      {"label": "defense", "sublabel": x["defense"].values[0],
       "range": [int(max(df["defense"])*0.5), int(max(df["defense"])*0.75), int(max(df["defense"]))], "performance": [int(max(df["defense"])*0.55),int(max(df["defense"])*0.70)], "point": [x["defense"].values[0]]},
      {"label": "special_attack", "sublabel": x["special_attack"].values[0],
       "range": [int(max(df["special_attack"])*0.5), int(max(df["special_attack"])*0.75), int(max(df["special_attack"]))], "performance": [int(max(df["special_attack"])*0.55),int(max(df["special_attack"])*0.70)], "point": [x["special_attack"].values[0]]},
      {"label": "special_defense", "sublabel": x["special_defense"].values[0],
       "range": [int(max(df["special_defense"])*0.5), int(max(df["special_defense"])*0.75), int(max(df["special_defense"]))], "performance": [int(max(df["special_defense"])*0.55),int(max(df["special_defense"])*0.70)], "point": [x["special_defense"].values[0]]},
      {"label": "speed", "sublabel": x["speed"].values[0],
       "range": [int(max(df["speed"])*0.5), int(max(df["speed"])*0.75), int(max(df["speed"]))], "performance": [int(max(df["speed"])*0.55),int(max(df["speed"])*0.70)], "point": [x["speed"].values[0]]}
    )
    
    fig = ff.create_bullet(
        data, titles='label', subtitles='sublabel', markers='point',
        measures='performance', ranges='range', orientation='v', width=800, height=800
    )

    iplot(fig, filename=f'bullet chart - skills and performance of {x["name"].values[0]}')

checkpokemonperformance("VenusaurMega Venusaur")

# %% [markdown]
# <a name="section-v-ten"></a>
# ### **Correlation Matrix**

# %%
plt.figure(figsize=(20,8))
corr_mx = df.corr(numeric_only=True)
mask = np.triu(corr_mx)
sns.heatmap(corr_mx,
            linewidths=0.5,
            square=True,
            cmap="RdBu_r",
            mask=mask,
            annot=True)
plt.title("Correlation Matrix")
plt.tight_layout()
